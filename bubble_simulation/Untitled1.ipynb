# %%
from bubble_simulation.analysis_pipeline import run_blog_analysis

# This single command generates EVERYTHING for your blog post!
results_path = run_blog_analysis(
    output_dir="./my_blog_analysis",
    num_timesteps=10,  # Adjust for depth vs speed
    scale="small"     # Perfect for blog post
)
# Out:
# Traditional CF: Model not trained, returning random recommendations
# Traditional CF: Model not trained, returning random recommendations
# Traditional CF: Model not trained, returning random recommendations
# Traditional CF: Model not trained, returning random recommendations
# Traditional CF: Model not trained, returning random recommendations
# Traditional CF: Model not trained, returning random recommendations
# Traditional CF: Model not trained, returning random recommendations
# Traditional CF: Model not trained, returning random recommendations
# Traditional CF: Model not trained, returning random recommendations
# Traditional CF: Model not trained, returning random recommendations
# Traditional CF: Model not trained, returning random recommendations
# Traditional CF: Model not trained, returning random recommendations
# Traditional CF: Model not trained, returning random recommendations
# Traditional CF: Model not trained, returning random recommendations
# ...
